# %% [markdown]
# # implementasi VSM TF-IDF menggunakan klasifikasi logistic regresion

# %% [markdown]
# ## proses melakukan logistic regresion

# %% [markdown]
# ### import library yang diperlukan

# %%
import pandas as pd
import string
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
import pickle

nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\OKTAVIAN\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\OKTAVIAN\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
df = pd.read_csv('berita_kompas.csv')

# %%
def preptext(text):
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = re.sub(r'\d+', '', text)
    words = word_tokenize(text.lower())

    sw = set(stopwords.words("indonesian" and "english"))
    words = [word for word in words if word not in sw]
    return ' '.join(words)

# %%
df['isi_baru'] = df['isi'].apply(preptext)

# %%
vector = TfidfVectorizer(max_features=1000)
x = vector.fit_transform(df['isi_baru'])
feature_names = vector.get_feature_names_out()

# %%
y = df['kategori']
y
# Out:
# 0         Nasional
# 1         Nasional
# 2      Megapolitan
# 3         Nasional
# 4      Megapolitan
#           ...
# 145    Megapolitan
# 146       Nasional
# 147    Megapolitan
# 148       Nasional
# 149    Megapolitan
# Name: kategori, Length: 150, dtype: object

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
from sklearn.decomposition import TruncatedSVD
from scipy.sparse import csr_matrix
import numpy as np

df_baru = pd.read_csv('tfidf_output.csv')

svd = TruncatedSVD(n_components=2870, n_iter=7, random_state=42)
data_baru = svd.fit_transform(df_baru)
# print(svd.explained_variance_ratio_)
data_baru.shape
type(data_baru)
hasil_data_baru = pd.DataFrame(data_baru) 
hasil_data_baru
# Out:
#           0         1         2         3         4         5         6    \
# 0    0.177558  0.021055 -0.070147 -0.068225  0.002461 -0.037005  0.028816
# 1    0.178072  0.044257 -0.003164 -0.074405 -0.015041 -0.039068  0.112848
# 2    0.192936  0.008030 -0.042562 -0.131636 -0.006761 -0.047112 -0.041141
# 3    0.361569  0.603967  0.592221  0.139251 -0.026001  0.001158 -0.068276
# 4    0.314437 -0.374981  0.226554 -0.000755 -0.047145  0.314779 -0.063884
# ..        ...       ...       ...       ...       ...       ...       ...
# 145  0.283092 -0.444376  0.300106  0.066473 -0.046510 -0.027795 -0.021061
# 146  0.210476  0.035060 -0.071931 -0.079636  0.035709 -0.056934  0.074476
# 147  0.407164 -0.603093  0.392920  0.117468 -0.059959 -0.028261 -0.013874
# 148  0.295391  0.045018 -0.095098 -0.115136 -0.045647 -0.033787  0.162656
# 149  0.224279  0.027206 -0.054728 -0.200987 -0.000348 -0.089371 -0.100069
#
#           7         8         9    ...       140       141       142  \
# 0   -0.019488  0.204220 -0.132958  ... -0.000283  0.000911 -0.000855
# 1   -0.019924 -0.068784 -0.022363  ... -0.001912 -0.002343  0.003492
# 2    0.065134 -0.041923 -0.009978  ... -0.000877 -0.000165 -0.000145
# 3   -0.008078  0.037325  0.020459  ...  0.092146 -0.021388  0.001211
# 4    0.001838 -0.033966  0.003552  ... -0.000758 -0.000706 -0.001823
# ..        ...       ...       ...  ...       ...       ...       ...
# 145  0.014540 -0.025848 -0.029130  ...  0.007321 -0.000040 -0.000208
# 146 -0.036042  0.239541  0.505140  ...  0.001895 -0.001218 -0.002324
# 147  0.008600 -0.020684 -0.026297  ... -0.004818  0.004869  0.009240
# 148 -0.017214  0.071692  0.026556  ... -0.007547  0.006643  0.011031
# 149  0.035062 -0.051944 -0.033653  ... -0.001075  0.000662  0.000656
#
#           143       144       145       146       147       148       149
# 0    0.000274 -0.000122 -0.000357 -0.000906 -0.000163 -0.000213 -0.000068
# 1   -0.001462  0.000533 -0.002705 -0.000235 -0.000507  0.000359 -0.001328
# 2   -0.000563  0.000761 -0.000697  0.000926 -0.000143 -0.000025 -0.000049
# 3   -0.011590 -0.010563 -0.102339 -0.040510  0.026497  0.001672  0.003391
# 4   -0.018417 -0.006036 -0.000385  0.000289 -0.000011 -0.001553  0.000632
# ..        ...       ...       ...       ...       ...       ...       ...
# 145  0.001386 -0.005688 -0.000457  0.002171  0.001738  0.005128 -0.001441
# 146  0.001541  0.001733 -0.000363 -0.000789 -0.001098 -0.000164 -0.001721
# 147  0.004864  0.193548 -0.016676 -0.006739 -0.007039 -0.059765  0.023493
# 148 -0.009481 -0.001873  0.002359  0.002409  0.000982  0.001742 -0.004945
# 149 -0.001043 -0.000158 -0.000672 -0.000125 -0.000417  0.000061  0.000060
#
# [150 rows x 150 columns]

# %%
hasil_data_baru['kategori'] = np.random.choice(['Megapolitan', 'Nasional'], size=len(hasil_data_baru))
hasil_data_baru
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.177558  0.021055 -0.070147 -0.068225  0.002461 -0.037005  0.028816
# 1    0.178072  0.044257 -0.003164 -0.074405 -0.015041 -0.039068  0.112848
# 2    0.192936  0.008030 -0.042562 -0.131636 -0.006761 -0.047112 -0.041141
# 3    0.361569  0.603967  0.592221  0.139251 -0.026001  0.001158 -0.068276
# 4    0.314437 -0.374981  0.226554 -0.000755 -0.047145  0.314779 -0.063884
# ..        ...       ...       ...       ...       ...       ...       ...
# 145  0.283092 -0.444376  0.300106  0.066473 -0.046510 -0.027795 -0.021061
# 146  0.210476  0.035060 -0.071931 -0.079636  0.035709 -0.056934  0.074476
# 147  0.407164 -0.603093  0.392920  0.117468 -0.059959 -0.028261 -0.013874
# 148  0.295391  0.045018 -0.095098 -0.115136 -0.045647 -0.033787  0.162656
# 149  0.224279  0.027206 -0.054728 -0.200987 -0.000348 -0.089371 -0.100069
#
#             7         8         9  ...       141       142       143  \
# 0   -0.019488  0.204220 -0.132958  ...  0.000911 -0.000855  0.000274
# 1   -0.019924 -0.068784 -0.022363  ... -0.002343  0.003492 -0.001462
# 2    0.065134 -0.041923 -0.009978  ... -0.000165 -0.000145 -0.000563
# 3   -0.008078  0.037325  0.020459  ... -0.021388  0.001211 -0.011590
# 4    0.001838 -0.033966  0.003552  ... -0.000706 -0.001823 -0.018417
# ..        ...       ...       ...  ...       ...       ...       ...
# 145  0.014540 -0.025848 -0.029130  ... -0.000040 -0.000208  0.001386
# 146 -0.036042  0.239541  0.505140  ... -0.001218 -0.002324  0.001541
# 147  0.008600 -0.020684 -0.026297  ...  0.004869  0.009240  0.004864
# 148 -0.017214  0.071692  0.026556  ...  0.006643  0.011031 -0.009481
# 149  0.035062 -0.051944 -0.033653  ...  0.000662  0.000656 -0.001043
#
#           144       145       146       147       148       149     kategori
# 0   -0.000122 -0.000357 -0.000906 -0.000163 -0.000213 -0.000068  Megapolitan
# 1    0.000533 -0.002705 -0.000235 -0.000507  0.000359 -0.001328  Megapolitan
# 2    0.000761 -0.000697  0.000926 -0.000143 -0.000025 -0.000049     Nasional
# 3   -0.010563 -0.102339 -0.040510  0.026497  0.001672  0.003391  Megapolitan
# 4   -0.006036 -0.000385  0.000289 -0.000011 -0.001553  0.000632     Nasional
# ..        ...       ...       ...       ...       ...       ...          ...
# 145 -0.005688 -0.000457  0.002171  0.001738  0.005128 -0.001441  Megapolitan
# 146  0.001733 -0.000363 -0.000789 -0.001098 -0.000164 -0.001721     Nasional
# 147  0.193548 -0.016676 -0.006739 -0.007039 -0.059765  0.023493     Nasional
# 148 -0.001873  0.002359  0.002409  0.000982  0.001742 -0.004945     Nasional
# 149 -0.000158 -0.000672 -0.000125 -0.000417  0.000061  0.000060     Nasional
#
# [150 rows x 151 columns]

# %%
LR = LogisticRegression(max_iter=1000)
LR.fit(xtrain,ytrain)

ypred = LR.predict(xtest)

# %%
print(feature_names)
# Out:
# ['abah' 'acara' 'ada' 'adalah' 'adanya' 'adapun' 'adita' 'agar' 'agung'
#  'agus' 'ahmad' 'aipda' 'air' 'airlangga' 'akan' 'akhir' 'akhirnya'
#  'akibat' 'aktif' 'aktivitas' 'akun' 'aleppo' 'alun' 'amanat' 'anak'
#  'anakanak' 'ancaman' 'anggaran' 'anggota' 'angka' 'antara' 'anungrano'
#  'ap' 'apa' 'apakah' 'aparat' 'apple' 'arab' 'arahan' 'artinya' 'asal'
#  'aset' 'atas' 'atau' 'aturan' 'awal' 'ayat' 'baca' 'badan' 'bagaimana'
#  'bagi' 'bagian' 'bahkan' 'bahwa' 'baik' 'bakal' 'bandar' 'bangka'
#  'banjir' 'bansos' 'bantuan' 'banyak' 'bapak' 'barang' 'barangbarang'
#  'barat' 'baru' 'basarnas' 'basuki' 'batam' 'bawah' 'bawaslu' 'bayi'
#  'baznas' 'bebas' 'beberapa' 'begitu' 'bekasi' 'bekerja' 'belakang'
#  'belum' 'bencana' 'berada' 'berapa' 'berbagai' 'berdasarkan' 'bergizi'
#  'berharap' 'berhasil' 'berikut' 'berinisial' 'berjalan' 'berkaitan'
#  'berkoordinasi' 'berlaku' 'berlangsung' 'bernama' 'beroperasi' 'bersalah'
#  'bersama' 'bersamasama' 'bersangkutan' 'bersifat' 'bertemu' 'berujung'
#  'berupa' 'berusaha' 'berwarna' 'besar' 'bgn' 'biasa' 'biaya' 'bidang'
#  'bilang' 'bisa' 'bnn' 'bogor' 'bpbd' 'bs' 'bsk' 'buat' 'budi' 'budiyanto'
#  'bukan' 'bukti' 'bulan' 'bumi' 'bumn' 'bunuh' 'cagubcawagub' 'calon'
#  'china' 'cianjur' 'cibitung' 'coba' 'count' 'cukup' 'daerah' 'daftar'
#  'dalam' 'dan' 'dana' 'dapat' 'dari' 'darurat' 'dasco' 'data' 'datang'
#  'daycare' 'dekat' 'demikian' 'demokrasi' 'denda' 'dengan' 'depan' 'depok'
#  'desember' 'desk' 'dewan' 'dewas' 'dewi' 'dharma' 'di' 'dia' 'diamuk'
#  'dianggap' 'diberikan' 'diberitakan' 'dibuka' 'didakwa' 'diduga'
#  'digunakan' 'dihubungi' 'dikenakan' 'dikenal' 'diketahui' 'dikurangi'
#  'dikutip' 'dilakukan' 'dilelang' 'dimulai' 'dinas' 'dinilai' 'dipimpin'
#  'direktorat' 'direktur' 'diri' 'disampaikan' 'disdik' 'disebut'
#  'diserahkan' 'disiram' 'disita' 'ditahan' 'ditangkap' 'ditemui'
#  'diterapkan' 'dituntut' 'diumumkan' 'diusung' 'dki' 'dkpp' 'dokter' 'dpp'
#  'dpr' 'dua' 'dugaan' 'dukungan' 'dulu' 'dunia' 'edukasi' 'ekonomi' 'eks'
#  'emil' 'empat' 'enam' 'energi' 'enggak' 'ermindra' 'es' 'etik' 'fahmi'
#  'faisal' 'fasilitas' 'februari' 'felicia' 'fitroh' 'formulir' 'fraksi'
#  'gadungan' 'gambir' 'gangguan' 'gas' 'gayung' 'gedung' 'gibran' 'gitu'
#  'gizi' 'golkar' 'golput' 'gratis' 'gubernur' 'gulung' 'guna' 'gunawan'
#  'gus' 'habiburrahman' 'hadir' 'hak' 'hakim' 'hal' 'halaman' 'halhal'
#  'hambatan' 'hanya' 'harapan' 'harga' 'hari' 'harta' 'harus' 'harvey'
#  'hasan' 'hasbi' 'hasil' 'hasto' 'helena' 'herlina' 'hery' 'hingga'
#  'hubungan' 'hujan' 'hukum' 'hukuman' 'ia' 'ibnu' 'ibu' 'ibunya' 'ichsan'
#  'ii' 'iii' 'ikut' 'imbuh' 'imigrasi' 'indonesia' 'informasi' 'ingin'
#  'ini' 'intelijen' 'internasional' 'interpol' 'inti' 'investasi' 'ipul'
#  'istana' 'itu' 'iup' 'iya' 'izin' 'jabatan' 'jadi' 'jadwal' 'jakarta'
#  'jaket' 'jaksa' 'jalan' 'jam' 'januari' 'jaringan' 'jasa' 'jawa' 'jawab'
#  'jelas' 'jenderal' 'jepang' 'jika' 'jiwa' 'jo' 'johanis' 'joko' 'jokowi'
#  'jual' 'judha' 'judi' 'juga' 'jumlah' 'justru' 'juta' 'kabinet'
#  'kabupaten' 'kaesang' 'kafe' 'kajian' 'kalau' 'kali' 'kami'
#  'kamilsuswono' 'kamis' 'kampung' 'kan' 'kandungnya' 'kantor' 'kapolri'
#  'karena' 'karno' 'kasasi' 'kasus' 'kata' 'katanya' 'kbri' 'kcb' 'ke'
#  'keamanan' 'kebakaran' 'kebijakan' 'kebutuhan' 'kecamatan' 'kecil'
#  'kedua' 'kegiatan' 'kejadian' 'kejaksaan' 'kejiwaan' 'kelayakan'
#  'kelompok' 'keluarga' 'kemarin' 'kembali' 'kemenlu' 'kemensos'
#  'kementerian' 'kemiskinan' 'kemudian' 'kemungkinan' 'kenaikan'
#  'kendaraan' 'kepada' 'kepala' 'kepatutan' 'kepentingan' 'kepolisian'
#  'keputusan' 'kerap' 'keras' 'kerja' 'kesehatan' 'kesejahteraan'
#  'kesempatan' 'keterangan' 'ketika' 'ketua' 'keuangan' 'keuntungan'
#  'khusus' 'khususnya' 'kiddy' 'kinerja' 'kini' 'kira' 'kita' 'kolaborasi'
#  'komisi' 'komite' 'kompascom' 'kompleks' 'kondisi' 'konferensi'
#  'konsumen' 'kontrakan' 'kontrol' 'koordinasi' 'koordinator' 'korban'
#  'koridor' 'korupsi' 'kosong' 'kota' 'kotak' 'kpk' 'kpu' 'kpud'
#  'kramatjati' 'kuhp' 'kuliah' 'kunjungan' 'kurungan' 'lagi' 'lain'
#  'lainnya' 'lalu' 'lama' 'laman' 'lambat' 'langkah' 'langsung' 'lanjut'
#  'lantai' 'lapas' 'laporan' 'laporkan' 'layanan' 'lebih' 'lelang'
#  'lembaga' 'liar' 'lim' 'lima' 'lintas' 'listyo' 'lokasi' 'longsor' 'luar'
#  'luka' 'maaf' 'mabes' 'maharani' 'mahkamah' 'majelis' 'maka' 'makan'
#  'makanan' 'maksimal' 'malam' 'malaysia' 'mana' 'mantan' 'mas' 'masa'
#  'masalah' 'masih' 'masingmasing' 'massa' 'masuk' 'masyarakat' 'mati'
#  'mau' 'maulana' 'maupun' 'mbg' 'media' 'melaksanakan' 'melakukan'
#  'melalui' 'melanggar' 'melanjutkan' 'melaporkan' 'melarikan' 'melawan'
#  'melepuh' 'melihat' 'memahami' 'memang' 'memantau' 'memastikan'
#  'membangun' 'membantu' 'membawa' 'membayar' 'memberi' 'memberikan'
#  'membuat' 'membunuh' 'memenuhi' 'memilih' 'memiliki' 'meminta'
#  'memperkaya' 'menaikkan' 'menang' 'mencapai' 'mendapat' 'mendapatkan'
#  'mendorong' 'mendukung' 'menegaskan' 'menekankan' 'menerima'
#  'mengakomodasi' 'mengaku' 'mengalami' 'mengatakan' 'mengenai'
#  'mengetahui' 'menggunakan' 'menghargai' 'menghubungi' 'mengikuti'
#  'mengimbau' 'mengungkapkan' 'mengurangi' 'menilai' 'menindaklanjuti'
#  'meningkatkan' 'menjadi' 'menjalani' 'menjalankan' 'menjatuhkan'
#  'menjelaskan' 'menko' 'menteri' 'menu' 'menunggu' 'menunjukkan'
#  'menuntut' 'menurut' 'menuturkan' 'menyampaikan' 'menyatakan' 'menyebut'
#  'menyebutkan' 'menyerahkan' 'menyiapkan' 'menyiramkan' 'mereka'
#  'merupakan' 'meski' 'metro' 'mewah' 'miftah' 'miliar' 'milik' 'minggu'
#  'minta' 'misbakhun' 'mobil' 'mochtar' 'moeis' 'motor' 'mr' 'mulai'
#  'mungkin' 'murid' 'musik' 'muslim' 'nah' 'nama' 'namun' 'nana' 'nani'
#  'nanti' 'narkoba' 'narkotika' 'nasional' 'ncb' 'negara' 'negeri' 'nikson'
#  'nilai' 'nomor' 'november' 'nuryati' 'oleh' 'online' 'operasi' 'orang'
#  'orangtua' 'ott' 'pada' 'pagar' 'pahlevi' 'pajak' 'pak' 'pakai' 'paling'
#  'palmerah' 'panas' 'pangaribuan' 'para' 'paripurna' 'parlemen' 'partai'
#  'partisipasi' 'pasal' 'pasangan' 'pasar' 'paslon' 'pasti' 'pdi' 'pdip'
#  'pedagang' 'pejabat' 'pekan' 'pelabuhan' 'pelajar' 'pelaksanaan' 'pelaku'
#  'pelanggaran' 'pelayanan' 'pemasyarakatan' 'pembangunan' 'pembeli'
#  'pemberantasan' 'pemberitahuan' 'pembina' 'pemenangan' 'pemeriksaan'
#  'pemerintah' 'pemerintahan' 'pemilih' 'pemilihan' 'pemilik' 'pemilu'
#  'pemkot' 'penanganan' 'penanggulangan' 'penangkapan' 'pencucian'
#  'pendidikan' 'penegakan' 'penetapan' 'pengadilan' 'penganiayaan'
#  'pengasinan' 'pengasuhnya' 'pengawas' 'pengawasan' 'pengganti' 'pengguna'
#  'pengusaha' 'penindakan' 'penjara' 'penjual' 'penting' 'pentingnya'
#  'penuntut' 'penurunan' 'penyebab' 'penyelenggara' 'per' 'perampasan'
#  'peraturan' 'perbankan' 'perbuatan' 'perbuatannya' 'percaya' 'peredaran'
#  'perempuan' 'perhitungan' 'perintah' 'periode' 'peristiwa' 'perjalanan'
#  'perjuangan' 'perkara' 'perkasa' 'perlindungan' 'perlu' 'permintaan'
#  'permohonan' 'pernah' 'pernyataan' 'perolehan' 'pers' 'persen' 'pertama'
#  'pertambahan' 'pertambangan' 'pertemuan' 'perusahaan' 'perwakilan'
#  'peserta' 'petisi' 'petugas' 'pgn' 'pidana' 'pihak' 'pihaknya' 'pilar'
#  'pilkada' 'pilkadakpugoid' 'pimpinan' 'pisau' 'pokok' 'pol' 'polisi'
#  'politik' 'politikus' 'polkam' 'polres' 'polri' 'potensi' 'ppn' 'prabowo'
#  'pramono' 'pramonorano' 'presiden' 'pria' 'prioritas' 'profesionalitas'
#  'program' 'proses' 'provinsi' 'pt' 'puan' 'publik' 'pukul' 'pula'
#  'pulang' 'pun' 'pungli' 'punya' 'pusat' 'putaran' 'putusan' 'qse' 'rabu'
#  'rafael' 'rakyat' 'rampung' 'rangka' 'rapat' 'real' 'rehabilitasi'
#  'rekap' 'rekapitulasi' 'remaja' 'rencana' 'rendah' 'rendahnya' 'resmi'
#  'ri' 'rido' 'ridwan' 'rieke' 'riza' 'rksuswono' 'ronald' 'ronny' 'rosan'
#  'rp' 'rs' 'rt' 'ruang' 'rumah' 'ruu' 'rw' 'saat' 'saga' 'sah' 'saja'
#  'sakit' 'saksi' 'salah' 'sama' 'sambungnya' 'sampai' 'sampaikan' 'sana'
#  'sandra' 'sang' 'sangat' 'sanksi' 'sarana' 'sarmuji' 'satu' 'satuan'
#  'satunya' 'saudi' 'sawangan' 'saya' 'sebab' 'sebagai' 'sebagaimana'
#  'sebagian' 'sebanyak' 'sebelum' 'sebelumnya' 'sebesar' 'sebuah' 'sebut'
#  'secara' 'sedang' 'sedangkan' 'seftyana' 'segera' 'sehingga' 'sejak'
#  'sejumlah' 'sekali' 'sekarang' 'sekitar' 'sekjen' 'sekolah' 'sekretaris'
#  'selain' 'selaku' 'selalu' 'selama' 'selanjutnya' 'selasa' 'selatan'
#  'selektif' 'selesai' 'seluruh' 'semakin' 'sementara' 'seminar' 'sempat'
#  'semua' 'senayan' 'sendiri' 'senilai' 'senin' 'seorang' 'sepeda'
#  'seperti' 'sering' 'serta' 'sesuai' 'setelah' 'setelahnya' 'setiap'
#  'setyo' 'siapa' 'siapkan' 'sidang' 'sikap' 'siram' 'sisi' 'sistem'
#  'siswa' 'situasi' 'situs' 'sman' 'smelter' 'soal' 'sosial' 'space'
#  'stunting' 'suami' 'suara' 'subianto' 'subsider' 'sudah' 'sufmi'
#  'suhyana' 'sukabumi' 'sumbangan' 'sunhaji' 'surat' 'suriah' 'tadi'
#  'tahap' 'tahapan' 'tahu' 'tahun' 'tak' 'tambah' 'tanah' 'tanak' 'tanda'
#  'tangan' 'tangerang' 'tanggal' 'tangsel' 'tanpa' 'tanya' 'tapi' 'tarif'
#  'tas' 'tbk' 'tegas' 'teh' 'telah' 'telur' 'tempat' 'tenaga' 'tengah'
#  'tentang' 'tentara' 'tentu' 'terakhir' 'terancam' 'terbuka' 'terbukti'
#  'terdakwa' 'terdampak' 'terdapat' 'terhadap' 'terjadi' 'terkait'
#  'terlalu' 'terlibat' 'terlihat' 'termasuk' 'teror' 'terpidana' 'terpilih'
#  'tersangka' 'tersebar' 'tersebut' 'terus' 'terutama' 'tetap' 'tetapi'
#  'tewas' 'tidak' 'tiga' 'tim' 'timah' 'timur' 'tin' 'tindak' 'tinggi'
#  'tingkat' 'tipikor' 'titik' 'tk' 'tki' 'total' 'tppu' 'tps' 'triliun'
#  'truk' 'tubuh' 'tugas' 'tukang' 'turut' 'tutup' 'tutur' 'tuturnya' 'uang'
#  'ucap' 'ujar' 'ujarnya' 'uji' 'ujian' 'ulang' 'umum' 'undangundang'
#  'unggul' 'ungkap' 'untuk' 'upaya' 'urut' 'usaha' 'usai' 'utama' 'utara'
#  'utusan' 'uu' 'video' 'wahyu' 'wakil' 'waktu' 'wali' 'warga' 'wib'
#  'widodo' 'wihaji' 'wilayah' 'wni' 'xi' 'ya' 'yaitu' 'yakni' 'yang'
#  'yulius' 'yusril' 'yz' 'zakat']

# %%
print(x)
# Out:
#   (0, 281)	0.04909174944263912
#   (0, 425)	0.02910847469843477
#   (0, 502)	0.04582073276592877
#   (0, 440)	0.026777572964871942
#   (0, 186)	0.03969020420392075
#   (0, 14)	0.01970692945971641
#   (0, 737)	0.03378574025319663
#   (0, 852)	0.04909174944263912
#   (0, 519)	0.0288288037037839
#   (0, 143)	0.015490707773513725
#   (0, 457)	0.039087279935495024
#   (0, 25)	0.05038449504165732
#   (0, 62)	0.043187285491914994
#   (0, 320)	0.05341111658935527
#   (0, 398)	0.026541678972266072
#   (0, 993)	0.036419187527210406
#   (0, 3)	0.03060047873691558
#   (0, 153)	0.01569938208471345
#   (0, 847)	0.037424355653538285
#   (0, 959)	0.05038449504165732
#   (0, 162)	0.027127125385184456
#   (0, 4)	0.03851001993715314
#   (0, 569)	0.044009571350636906
#   (0, 789)	0.040321181352444994
#   (0, 817)	0.09818349888527823
#   :	:
#   (149, 162)	0.0946667571814374
#   (149, 918)	0.10735395112852722
#   (149, 872)	0.054490829030839114
#   (149, 388)	0.06155942307442921
#   (149, 935)	0.014440771522202628
#   (149, 517)	0.03031214440237238
#   (149, 902)	0.05406149471101928
#   (149, 140)	0.07411893571721899
#   (149, 323)	0.07362970003000686
#   (149, 47)	0.04235367755269657
#   (149, 962)	0.03520497690899639
#   (149, 917)	0.04898269192229341
#   (149, 359)	0.06961645297369601
#   (149, 971)	0.035799115077992674
#   (149, 299)	0.023021255976476127
#   (149, 798)	0.11286795728020299
#   (149, 286)	0.08079378965921125
#   (149, 596)	0.07021899401929092
#   (149, 929)	0.045197455405474464
#   (149, 17)	0.09696529310940297
#   (149, 995)	0.10729609811110169
#   (149, 775)	0.047191102651739626
#   (149, 342)	0.018605011304326548
#   (149, 402)	0.010800922142400284
#   (149, 301)	0.012506173893280249

# %%
print('')
score_acc = accuracy_score(ytest,ypred)
print(f"score akurasi : {score_acc:.4f}" )
# Out:
# score akurasi : 0.8667

# %%
print(classification_report(ytest, ypred))
# Out:
#               precision    recall  f1-score   support
#
#  Megapolitan       1.00      0.75      0.86        16
#     Nasional       0.78      1.00      0.88        14
#
#     accuracy                           0.87        30
#    macro avg       0.89      0.88      0.87        30
# weighted avg       0.90      0.87      0.87        30

# %%
with open('logistic_regression_and_vectorizer.pkl', 'wb') as file:
    pickle.dump({'model': LR, 'vectorizer': vector}, file)
